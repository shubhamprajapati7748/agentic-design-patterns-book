# %%
import os
import asyncio
from typing import Optional

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import Runnable, RunnableParallel, RunnablePassthrough

# --- Configuration ---
# Ensure your API key environment variable is set (e.g., OPENAI_API_KEY)

try:
    llm: Optional[ChatOpenAI] = ChatOpenAI(model="gpt-4o-mini", temperature=0.7)
    if llm:
        print(f"Language model initialized: {llm.model_name}")
except Exception as e:
    print(f"Error initializing language model: {e}")
    llm = None


# --- Define Independent Chains ---
# These three chains represent distinct tasks that can be executed in parallel.

summarize_chain: Runnable = (
    ChatPromptTemplate.from_messages([
        ("system", "Summarize the following topic concisely:"),
        ("user", "{topic}")
    ])
    | llm
    | StrOutputParser()
)

questions_chain: Runnable = (
    ChatPromptTemplate.from_messages([
        ("system", "Generate three interesting questions about the following topic:"),
        ("user", "{topic}")
    ])
    | llm
    | StrOutputParser()
)

terms_chain: Runnable = (
    ChatPromptTemplate.from_messages([
        ("system", "Identify 5-10 key terms from the following topic, separated by commas:"),
        ("user", "{topic}")
    ])
    | llm
    | StrOutputParser()
)


# --- Build the Parallel + Synthesis Chain ---

# 1. Define the block of tasks to run in parallel. The results of these,
#    along with the original topic, will be fed into the next step.
map_chain = RunnableParallel(
    {
        "summary": summarize_chain,
        "questions": questions_chain,
        "key_terms": terms_chain,
        "topic": RunnablePassthrough(),  # Pass the original topic through
    }
)

# 2. Define the final synthesis prompt which will combine the parallel results.
synthesis_prompt = ChatPromptTemplate.from_messages([
    ("system", """Based on the following information:
     Summary: {summary}
     Related Questions: {questions}
     Key Terms: {key_terms}
     Synthesize a comprehensive answer."""),
    ("user", "Original topic: {topic}")
])

# 3. Construct the full chain by piping the parallel results directly
#    into the synthesis prompt, followed by the LLM and output parser.
full_parallel_chain = map_chain | synthesis_prompt | llm | StrOutputParser()


# --- Run the Chain ---
async def run_parallel_example(topic: str) -> None:
    """
    Asynchronously invokes the parallel processing chain with a specific topic
    and prints the synthesized result.

    Args:
        topic: The input topic to be processed by the LangChain chains.
    """
    if not llm:
        print("LLM not initialized. Cannot run example.")
        return

    print(f"\n--- Running Parallel LangChain Example for Topic: '{topic}' ---")
    try:
        # The input to `ainvoke` is the single 'topic' string, which is
        # then passed to each runnable in the `map_chain`.
        response = await full_parallel_chain.ainvoke(topic)
        print("\n--- Final Response ---")
        print(response)
    except Exception as e:
        print(f"\nAn error occurred during chain execution: {e}")

# if __name__ == "__main__":
#     test_topic = "The history of space exploration"
#     # In Python 3.7+, asyncio.run is the standard way to run an async function.
#     asyncio.run(run_parallel_example(test_topic))
# Out:
# Language model initialized: gpt-4o-mini

# %%
test_topic = "The history of space exploration"
await run_parallel_example(test_topic)
# Out:
# --- Running Parallel LangChain Example for Topic: 'The history of space exploration' ---
#
# --- Final Response ---
# The history of space exploration is a remarkable narrative that showcases humanity's quest for knowledge beyond our planet. It began in the mid-20th century, a period characterized by intense geopolitical rivalry known as the Cold War, primarily between the United States and the Soviet Union. This rivalry was instrumental in shaping the early milestones of space exploration.
#
# **1. Cold War and Early Milestones:**
# The launch of Sputnik 1 by the Soviet Union on October 4, 1957, marked a pivotal moment in history, as it was the first artificial satellite to orbit the Earth. This event not only demonstrated the Soviet Union's technological prowess but also ignited the Space Race, prompting the United States to accelerate its own space program. The subsequent achievements in space exploration were closely tied to this competition, exemplified by Yuri Gagarin becoming the first human in space in 1961 and the historic Apollo 11 mission in 1969, which successfully landed astronauts Neil Armstrong and Buzz Aldrin on the Moon. These milestones were not only technological triumphs but also symbols of national superiority and ideological victory.
#
# **2. Recent Advancements and Transformation:**
# In the decades that followed, space exploration evolved significantly. The establishment of space stations, such as the International Space Station (ISS), and robotic missions to other planets, including Mars rovers and the deployment of the Hubble Space Telescope, expanded our understanding of the cosmos. Recently, advancements in technology have further transformed the landscape of space exploration. The emergence of private space companies, like SpaceX and Blue Origin, and the development of reusable rocket technology have drastically reduced the cost of access to space. This shift towards commercialization promises a future where space travel could become more accessible to the public, potentially leading to a new era of exploration and tourism beyond Earth.
#
# **3. Ethical Considerations and Challenges:**
# As we advance into this new frontier, several ethical considerations and challenges arise. One significant concern is planetary protection, which involves preventing biological contamination of other celestial bodies and ensuring that Earth’s biosphere is also protected from extraterrestrial materials. The potential for human colonization of planets like Mars raises questions about our responsibilities to preserve these environments and the implications of altering extraterrestrial ecosystems. Furthermore, the commercialization of space poses ethical dilemmas regarding resource allocation, potential exploitation of space resources, and the governance of space activities.
#
# In conclusion, the history of space exploration reflects not only remarkable technological advancements but also the complex interplay of political, ethical, and social factors. As we look toward the future, the lessons learned from past missions and the ongoing dialogue about ethical responsibilities will be crucial in guiding humanity's continued exploration of the cosmos.
